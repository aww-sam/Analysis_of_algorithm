# %%
def Partition(A,low,high):
    pivot=A[low]
    x=low+1
    y=high

    while x<=y:
        while x<=high and A[x]<=pivot :
            x=x+1
        while y>=(low+1) and A[y]>=pivot:
            y=y-1
        if x<y:
            A[x],A[y]=A[y],A[x]
    A[low],A[y]=A[y],A[low]
    return y

def quickSort(A,low,high):
    if low<high:
        p=Partition(A,low,high)
        quickSort(A,low,p-1)
        quickSort(A,p+1,high)

# %%
arr=[44,22,33,77,11,55,66,5,223]
print('Original array: ', arr)
quickSort(arr,0,len(arr)-1)
print('sorted array: ', arr)
# Out:
# Original array:  [44, 22, 33, 77, 11, 55, 66, 5, 223]
# sorted array:  [5, 11, 22, 33, 44, 55, 66, 77, 223]
